# %% [markdown]
# ## Ngodarpan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import re

# %%
ngodarpan = pd.read_json("ngodarpan.json")
ngodarpan.head()
# Out:
#    SrNo                                         Name  \
# 0     1        A & N KAYAKING & CANEOING ASSOCIATION
# 1     2  A S MUSIC AND DANCE A CULTURAL ORGANIZATION
# 2     3                        Abhishweta Foundation
# 3     4                           AdityaNatyaAcademy
# 4     5                                  Anandodhara
#
#                                         Registration  \
# 0       1544, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
# 1       1534, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 2  20211011RS00016, Port Blair (ANDAMAN & NICOBAR...
# 3        888, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 4       1355, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
#
#                                              Address  \
# 0  C/O STATE OLYMPIC ASSOCIATION\nNETAJI STADIUM\...
# 1  AS Music And Dance A Cultural Organization,\n8...
# 2  Room No.604(1)-MB550, Near Urban Health Centre...
# 3  31 M.G. Road,\nOpp. Sun Sea Resort,\nMiddle Po...
# 4  C/o Baakprotima (SBI Building)\nJunglighat\nPo...
#
#                                        SectorWorking
# 0                                             Sports
# 1                                     Data Not Found
# 2  Science & Technology,Art & Culture,Biotechnolo...
# 3  Art & Culture,Children,Education & Literacy,Sk...
# 4                                      Art & Culture

# %%
# remove "\n \r \t " in Name & Registration & Address & SectorWorking column
ngodarpan["Name"] = ngodarpan['Name'].replace('\n|\r|\t','', regex=True)
ngodarpan["Registration"] = ngodarpan['Registration'].replace('\n|\r|\t','', regex=True)
ngodarpan["Address"] = ngodarpan['Address'].replace('\n|\r|\t','', regex=True)
ngodarpan["SectorWorking"] = ngodarpan['SectorWorking'].replace('\n|\r|\t','', regex=True)

# %%
# For the Name and Address Column, make only the first letter of each word be capitalized
ngodarpan["Name"] = ngodarpan["Name"].str.title()
ngodarpan["Address"] = ngodarpan["Address"].str.title()

# %%
ngodarpan.head()
# Out:
#    SrNo                                         Name  \
# 0     1        A & N Kayaking & Caneoing Association
# 1     2  A S Music And Dance A Cultural Organization
# 2     3                        Abhishweta Foundation
# 3     4                           Adityanatyaacademy
# 4     5                                  Anandodhara
#
#                                         Registration  \
# 0       1544, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
# 1       1534, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 2  20211011RS00016, Port Blair (ANDAMAN & NICOBAR...
# 3        888, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 4       1355, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
#
#                                              Address  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...
# 1  As Music And Dance A Cultural Organization,8,A...
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...
#
#                                        SectorWorking
# 0                                             Sports
# 1                                     Data Not Found
# 2  Science & Technology,Art & Culture,Biotechnolo...
# 3  Art & Culture,Children,Education & Literacy,Sk...
# 4                                      Art & Culture

# %% [markdown]
# ## Registration

# %% [markdown]
# ### RegNo

# %%
# Extract the Registration number from Registration column
ngodarpan['RegNo'] = ngodarpan['Registration'].str.extract(r'(.*),')
ngodarpan.head()
# Out:
#    SrNo                                         Name  \
# 0     1        A & N Kayaking & Caneoing Association
# 1     2  A S Music And Dance A Cultural Organization
# 2     3                        Abhishweta Foundation
# 3     4                           Adityanatyaacademy
# 4     5                                  Anandodhara
#
#                                         Registration  \
# 0       1544, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
# 1       1534, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 2  20211011RS00016, Port Blair (ANDAMAN & NICOBAR...
# 3        888, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 4       1355, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
#
#                                              Address  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...
# 1  As Music And Dance A Cultural Organization,8,A...
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...
#
#                                        SectorWorking            RegNo
# 0                                             Sports             1544
# 1                                     Data Not Found             1534
# 2  Science & Technology,Art & Culture,Biotechnolo...  20211011RS00016
# 3  Art & Culture,Children,Education & Literacy,Sk...              888
# 4                                      Art & Culture             1355

# %% [markdown]
# ### City

# %%
# Extract the City from Registration column
ngodarpan['City'] = ngodarpan['Registration'].str.extract(r',(.*)\(')
ngodarpan['City'] = ngodarpan['City'].str.title()
ngodarpan.head()
# Out:
#    SrNo                                         Name  \
# 0     1        A & N Kayaking & Caneoing Association
# 1     2  A S Music And Dance A Cultural Organization
# 2     3                        Abhishweta Foundation
# 3     4                           Adityanatyaacademy
# 4     5                                  Anandodhara
#
#                                         Registration  \
# 0       1544, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
# 1       1534, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 2  20211011RS00016, Port Blair (ANDAMAN & NICOBAR...
# 3        888, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 4       1355, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
#
#                                              Address  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...
# 1  As Music And Dance A Cultural Organization,8,A...
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...
#
#                                        SectorWorking            RegNo  \
# 0                                             Sports             1544
# 1                                     Data Not Found             1534
# 2  Science & Technology,Art & Culture,Biotechnolo...  20211011RS00016
# 3  Art & Culture,Children,Education & Literacy,Sk...              888
# 4                                      Art & Culture             1355
#
#            City
# 0   Port Blair
# 1   Port Blair
# 2   Port Blair
# 3   Port Blair
# 4   Port Blair

# %%
# Visualize the most frequent Cities that appeared (top 5)
city_count = ngodarpan['City'].value_counts().head()
plt.bar(city_count.index, city_count)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### State

# %%
# Extract the State from Registration column
ngodarpan['State'] = ngodarpan['Registration'].str.extract(r'\((.*)\)')
ngodarpan['State'] = ngodarpan['State'].str.title()
ngodarpan.head()
# Out:
#    SrNo                                         Name  \
# 0     1        A & N Kayaking & Caneoing Association
# 1     2  A S Music And Dance A Cultural Organization
# 2     3                        Abhishweta Foundation
# 3     4                           Adityanatyaacademy
# 4     5                                  Anandodhara
#
#                                         Registration  \
# 0       1544, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
# 1       1534, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 2  20211011RS00016, Port Blair (ANDAMAN & NICOBAR...
# 3        888, Port Blair (ANDAMAN & NICOBAR ISLANDS)
# 4       1355, PORT BLAIR (ANDAMAN & NICOBAR ISLANDS)
#
#                                              Address  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...
# 1  As Music And Dance A Cultural Organization,8,A...
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...
#
#                                        SectorWorking            RegNo  \
# 0                                             Sports             1544
# 1                                     Data Not Found             1534
# 2  Science & Technology,Art & Culture,Biotechnolo...  20211011RS00016
# 3  Art & Culture,Children,Education & Literacy,Sk...              888
# 4                                      Art & Culture             1355
#
#            City                      State
# 0   Port Blair   Andaman & Nicobar Islands
# 1   Port Blair   Andaman & Nicobar Islands
# 2   Port Blair   Andaman & Nicobar Islands
# 3   Port Blair   Andaman & Nicobar Islands
# 4   Port Blair   Andaman & Nicobar Islands

# %%
state_count = ngodarpan['State'].value_counts()
state_count
# Out:
# Uttar Pradesh                                23956
# Maharashtra                                  19871
# Delhi                                        12618
# West Bengal                                  12197
# Tamil Nadu                                   11191
#                                              ...
# Chanda), Bhadrawati (Maharashtra                 1
# Gad), Kurkheda (Maharashtra                      1
# Beed), Mah/30/2002, Nathapur (Maharashtra        1
# Parbhani), Isapur Ramana (Maharashtra            1
# Org)899/2019, Diking (Arunachal Pradesh          1
# Name: State, Length: 2893, dtype: int64

# %%
# Re-order the columns and Delete the Registration column
ngodarpan = ngodarpan.reindex(['SrNo','Name','RegNo','State','City','Address','SectorWorking'], axis=1) 
ngodarpan.head()
# Out:
#    SrNo                                         Name            RegNo  \
# 0     1        A & N Kayaking & Caneoing Association             1544
# 1     2  A S Music And Dance A Cultural Organization             1534
# 2     3                        Abhishweta Foundation  20211011RS00016
# 3     4                           Adityanatyaacademy              888
# 4     5                                  Anandodhara             1355
#
#                        State          City  \
# 0  Andaman & Nicobar Islands   Port Blair
# 1  Andaman & Nicobar Islands   Port Blair
# 2  Andaman & Nicobar Islands   Port Blair
# 3  Andaman & Nicobar Islands   Port Blair
# 4  Andaman & Nicobar Islands   Port Blair
#
#                                              Address  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...
# 1  As Music And Dance A Cultural Organization,8,A...
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...
#
#                                        SectorWorking
# 0                                             Sports
# 1                                     Data Not Found
# 2  Science & Technology,Art & Culture,Biotechnolo...
# 3  Art & Culture,Children,Education & Literacy,Sk...
# 4                                      Art & Culture

# %% [markdown]
# ## Address

# %%
# Extract the PIN from Address column and add this new column after Address
ngodarpan['PIN']=ngodarpan['Address'].str.extract(r'([0-9]{6})')
ngodarpan = ngodarpan.reindex(['SrNo','Name','RegNo','State','City','Address','PIN','SectorWorking'], axis=1)

# %%
ngodarpan.head()
# Out:
#    SrNo                                         Name            RegNo  \
# 0     1        A & N Kayaking & Caneoing Association             1544
# 1     2  A S Music And Dance A Cultural Organization             1534
# 2     3                        Abhishweta Foundation  20211011RS00016
# 3     4                           Adityanatyaacademy              888
# 4     5                                  Anandodhara             1355
#
#                        State          City  \
# 0  Andaman & Nicobar Islands   Port Blair
# 1  Andaman & Nicobar Islands   Port Blair
# 2  Andaman & Nicobar Islands   Port Blair
# 3  Andaman & Nicobar Islands   Port Blair
# 4  Andaman & Nicobar Islands   Port Blair
#
#                                              Address     PIN  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...     NaN
# 1  As Music And Dance A Cultural Organization,8,A...  744102
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...  744103
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.     NaN
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...  744103
#
#                                        SectorWorking
# 0                                             Sports
# 1                                     Data Not Found
# 2  Science & Technology,Art & Culture,Biotechnolo...
# 3  Art & Culture,Children,Education & Literacy,Sk...
# 4                                      Art & Culture

# %% [markdown]
# ## SectorWorking

# %%
len(ngodarpan[ngodarpan["SectorWorking"] == "Data Not Found"])
# Out:
# 33473

# %%
# Replace "Data Not Found" with "NaN" to keep consistency with the PIN column

# %%
ngodarpan["SectorWorking"] = ngodarpan['SectorWorking'].replace('Data Not Found','NaN', regex=True)
ngodarpan.head()
# Out:
#    SrNo                                         Name            RegNo  \
# 0     1        A & N Kayaking & Caneoing Association             1544
# 1     2  A S Music And Dance A Cultural Organization             1534
# 2     3                        Abhishweta Foundation  20211011RS00016
# 3     4                           Adityanatyaacademy              888
# 4     5                                  Anandodhara             1355
#
#                        State          City  \
# 0  Andaman & Nicobar Islands   Port Blair
# 1  Andaman & Nicobar Islands   Port Blair
# 2  Andaman & Nicobar Islands   Port Blair
# 3  Andaman & Nicobar Islands   Port Blair
# 4  Andaman & Nicobar Islands   Port Blair
#
#                                              Address     PIN  \
# 0  C/O State Olympic Associationnetaji Stadiumpor...     NaN
# 1  As Music And Dance A Cultural Organization,8,A...  744102
# 2  Room No.604(1)-Mb550, Near Urban Health Centre...  744103
# 3     31 M.G. Road,Opp. Sun Sea Resort,Middle Point.     NaN
# 4  C/O Baakprotima (Sbi Building)Junglighatport B...  744103
#
#                                        SectorWorking
# 0                                             Sports
# 1                                                NaN
# 2  Science & Technology,Art & Culture,Biotechnolo...
# 3  Art & Culture,Children,Education & Literacy,Sk...
# 4                                      Art & Culture

# %% [markdown]
# ## Cleaned Ngodarpan

# %%
ngodarpan
# Out:
#         SrNo                                               Name  \
# 0          1              A & N Kayaking & Caneoing Association
# 1          2        A S Music And Dance A Cultural Organization
# 2          3                              Abhishweta Foundation
# 3          4                                 Adityanatyaacademy
# 4          5                                        Anandodhara
# ...      ...                                                ...
# 165265     6                                      Ajins Society
# 165266     7  Akarum Society For Eco Tourism & Wildlife Cons...
# 165267     8        All Arunachal Computer Institute Federation
# 165268     9      All Arunachal Pradesh Divyang Welfare Society
# 165269    10      All Arunachal Pradesh Gorkha Welfare Society
#
#                   RegNo                      State          City  \
# 0                  1544  Andaman & Nicobar Islands   Port Blair
# 1                  1534  Andaman & Nicobar Islands   Port Blair
# 2       20211011RS00016  Andaman & Nicobar Islands   Port Blair
# 3                   888  Andaman & Nicobar Islands   Port Blair
# 4                  1355  Andaman & Nicobar Islands   Port Blair
# ...                 ...                        ...           ...
# 165265       SR/ITA3379          Arunachal Pradesh   Naharlagun
# 165266       SR/ITA/859          Arunachal Pradesh    Jairampur
# 165267      SR/ITA/7087          Arunachal Pradesh     Itanagar
# 165268      SR/ITA/5507          Arunachal Pradesh   Naharlagun
# 165269      SR/ITA/4057          Arunachal Pradesh     Itanagar
#
#                                                   Address     PIN  \
# 0       C/O State Olympic Associationnetaji Stadiumpor...     NaN
# 1       As Music And Dance A Cultural Organization,8,A...  744102
# 2       Room No.604(1)-Mb550, Near Urban Health Centre...  744103
# 3          31 M.G. Road,Opp. Sun Sea Resort,Middle Point.     NaN
# 4       C/O Baakprotima (Sbi Building)Junglighatport B...  744103
# ...                                                   ...     ...
# 165265  Papu Nallah, Naharlagun, Papumpare District Ar...     NaN
# 165266  Jairampur, Changlang District, Arunachal Prade...  792121
# 165267  Chimpu, Itanagar, Po-Rk Mission, Ps- Itanagar,...  791113
# 165268                   Takar Colony Borapani Naharlagun     NaN
# 165269  Office Of Theall Arunachal Pradesh Gorkha Welf...  791111
#
#                                             SectorWorking
# 0                                                  Sports
# 1                                                     NaN
# 2       Science & Technology,Art & Culture,Biotechnolo...
# 3       Art & Culture,Children,Education & Literacy,Sk...
# 4                                           Art & Culture
# ...                                                   ...
# 165265  Agriculture,Environment & Forests,Tribal Affai...
# 165266  Agriculture,Animal Husbandry, Dairying  &  Fis...
# 165267  Civic Issues,Education & Literacy,Health & Fam...
# 165268                                                NaN
# 165269                  Women's Development & Empowerment
#
# [165270 rows x 8 columns]

# %%
# Export the cleaned ngodarpan as the csv file
(ngodarpan.set_index('SrNo')).to_csv('cleaned_ngodarpan.csv')
